# %% [markdown]
# <a href="https://colab.research.google.com/github/p4vlos/AlexandrineRibeiro/blob/master/Denoiser_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uq denoiser
# Out:
#      |████████████████████████████████| 49 kB 3.1 MB/s
#      |████████████████████████████████| 58 kB 5.2 MB/s
#      |████████████████████████████████| 72 kB 639 kB/s
# ...

# %%
from IPython import display as disp
import torch
import torchaudio
from denoiser import pretrained
from denoiser.dsp import convert_audio

# %%
# Out:
# --2022-09-06 11:50:50--  https://facebookresearch.github.io/denoiser/audio/noisy/alex_noisy.mp
# Resolving facebookresearch.github.io (facebookresearch.github.io)... 185.199.111.153, 185.199.108.153, 185.199.110.153, ...
# Connecting to facebookresearch.github.io (facebookresearch.github.io)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-09-06 11:50:50 ERROR 404: Not Found.

# %%
model = pretrained.dns64().cuda()
wav, sr = torchaudio.load("/content/1-137-A-32.wav")
wav = convert_audio(wav.cuda(), sr, model.sample_rate, model.chin)
with torch.no_grad():
    denoised = model(wav[None])[0]
disp.display(disp.Audio(wav.data.cpu().numpy(), rate=model.sample_rate))
disp.display(disp.Audio(denoised.data.cpu().numpy(), rate=model.sample_rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
background = wav - denoised
disp.display(disp.Audio(background.data.cpu().numpy(), rate=model.sample_rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
